# %% [markdown]
# # 04 Fairness Metrics

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))
from src.experiments.runner import run_single_experiment

result = run_single_experiment(label_bias_strength=0.25)
result['group_summary']
