# %% [markdown]
# # 03 Model Training

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))
from src.experiments.runner import run_single_experiment

result = run_single_experiment()
result['performance'], result['fairness']
