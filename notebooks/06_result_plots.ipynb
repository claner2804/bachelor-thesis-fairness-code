# %% [markdown]
# # 06 Result Plots

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))
from src.experiments.runner import run_single_experiment
from src.visualization.plots_fairness import plot_group_metric_bars

result = run_single_experiment(label_bias_strength=0.2)
fig = plot_group_metric_bars(result['group_summary'])
fig
