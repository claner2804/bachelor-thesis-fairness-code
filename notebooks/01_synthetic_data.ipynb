# %% [markdown]
# # 01 Synthetic Data
# Erster Blick auf den synthetischen Datensatz.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))
from src.data.synthetic import generate_synthetic_data

df = generate_synthetic_data(n_samples=500, group_proportion=0.5, random_state=42)
df.head()
