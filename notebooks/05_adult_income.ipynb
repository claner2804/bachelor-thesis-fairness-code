# %% [markdown]
# # 05 Adult Income
# Platzhalter für den späteren realen Datensatz.

# %%
from pathlib import Path
path = Path('../data/raw/adult_income.csv')
print('Datei vorhanden:', path.exists())
