# %% [markdown]
# # 02 Bias Injection
# Teste Gruppenungleichgewicht und Label-Bias.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))
from src.data.synthetic import generate_synthetic_data
from src.bias.injection import inject_group_imbalance, inject_label_bias

df = generate_synthetic_data()
df_imb = inject_group_imbalance(df, target_proportion=0.3)
df_bias = inject_label_bias(df_imb, bias_strength=0.2)
df_bias.head()
